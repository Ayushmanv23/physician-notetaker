# %%
conversation = """
Patient was involved in a car accident on September 1st.
She experienced neck and back pain for four weeks.
She was diagnosed with a whiplash injury.
Treatment included painkillers and ten physiotherapy sessions.
Currently, she experiences occasional back pain.
Prognosis is full recovery within six months.
"""

print(conversation)
# Out:
# Patient was involved in a car accident on September 1st.
# She experienced neck and back pain for four weeks.
# She was diagnosed with a whiplash injury.
# Treatment included painkillers and ten physiotherapy sessions.
# Currently, she experiences occasional back pain.
# Prognosis is full recovery within six months.

# %%
medical_summary = {
    "Patient_Name": "Ms. Jones",
    "Symptoms": ["Neck pain", "Back pain", "Head impact"],
    "Diagnosis": "Whiplash injury",
    "Treatment": ["Painkillers", "10 physiotherapy sessions"],
    "Current_Status": "Occasional back pain",
    "Prognosis": "Full recovery expected within six months"
}

medical_summary
# Out:
# {'Patient_Name': 'Ms. Jones',
#  'Symptoms': ['Neck pain', 'Back pain', 'Head impact'],
#  'Diagnosis': 'Whiplash injury',
#  'Treatment': ['Painkillers', '10 physiotherapy sessions'],
#  'Current_Status': 'Occasional back pain',
#  'Prognosis': 'Full recovery expected within six months'}

# %%
keywords = [
    "Car accident",
    "Whiplash injury",
    "Neck pain",
    "Back pain",
    "Physiotherapy sessions",
    "Painkillers"
]

keywords
# Out:
# ['Car accident',
#  'Whiplash injury',
#  'Neck pain',
#  'Back pain',
#  'Physiotherapy sessions',
#  'Painkillers']

# %%
patient_statement = "That’s a relief! I was worried about my back pain."

if "worried" in patient_statement.lower():
    sentiment = "Anxious"
    intent = "Seeking reassurance"
elif "relief" in patient_statement.lower():
    sentiment = "Reassured"
    intent = "Expressing relief"
else:
    sentiment = "Neutral"
    intent = "Providing information"

{
    "Sentiment": sentiment,
    "Intent": intent
}
# Out:
# {'Sentiment': 'Anxious', 'Intent': 'Seeking reassurance'}

# %%
soap_note = {
    "Subjective": {
        "Chief_Complaint": "Neck and back pain",
        "History_of_Present_Illness": "Patient experienced pain after a car accident, improved after physiotherapy."
    },
    "Objective": {
        "Physical_Exam": "Full range of motion, no tenderness.",
        "Observations": "Patient stable and comfortable."
    },
    "Assessment": {
        "Diagnosis": "Whiplash injury",
        "Severity": "Mild and improving"
    },
    "Plan": {
        "Treatment": "No further intervention required",
        "Follow_Up": "Return if symptoms worsen"
    }
}

soap_note
# Out:
# {'Subjective': {'Chief_Complaint': 'Neck and back pain',
#   'History_of_Present_Illness': 'Patient experienced pain after a car accident, improved after physiotherapy.'},
#  'Objective': {'Physical_Exam': 'Full range of motion, no tenderness.',
#   'Observations': 'Patient stable and comfortable.'},
#  'Assessment': {'Diagnosis': 'Whiplash injury',
#   'Severity': 'Mild and improving'},
#  'Plan': {'Treatment': 'No further intervention required',
#   'Follow_Up': 'Return if symptoms worsen'}}
